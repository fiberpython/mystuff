# %%
print "watch yourself again"
# Out:
# watch yourself again

# %%
def double_list(alist):
    for i in range(len(alist)):
        alist[i] = 2 * alist[i]

x = [1, 2, 3, 4, 5]
double_list(x)
print x  
double_list(x)
print x
double_list(x)
double_list(x)
double_list(x)
double_list(x)
double_list(x)
print x
# Out:
# [2, 4, 6, 8, 10]
# [4, 8, 12, 16, 20]
# [128, 256, 384, 512, 640]

# %%
print

# %%
import os

os.chdir('/Users/pturner')

print(os.getcwd())

for f in os.listdir('/Users/pturner'):
    file_name, file_ext = os.path.splitext(f)
    print('{}-{}'.format(file_name,file_ext))
# Out:
# /Users/pturner
# .3T-
# .adobe-
# .android-
# .atom-
# .aws-
# .awsbkup-
# .bash_history-
# .bash_profile-
# .bash_profile-anaconda2-.bak
# .bash_profile-.backup
# .bash_sessions-
# .bashrc-
# .berkshelf-
# .boto-
# .cache-
# .CF89AA64-
# .CFUserTextEncoding-
# .chef-
# .chefdk-
# .conda-
# .config-
# .cpan-
# .dbshell-
# .digrc-
# .docker-
# .dropbox-
# .DS_Store-
# .dvdcss-
# .electron-
# .elinks-
# .fontconfig-
# .gdb_history-
# .gem-
# .gemrc-
# .gitconfig-
# .gitignore_global-
# .gitkraken-
# .gnupg-
# .gnupgbackup-
# .gradle-
# .gsutil-
# .hgignore_global-
# .IdentityService-
# .idlerc-
# .inspec-
# .intofo-.swp
# .ipynb_checkpoints-
# .ipython-
# .irb_history-
# .jenv-
# .jupyter-
# .kitchen-
# .kite-
# .lesshst-
# .local-
# .macports-
# .matplotlib-
# .mkshrc-
# .mongorc-.js
# .Netilla-
# .node-gyp-
# .node_repl_history-
# .npm-
# .nuget-
# .nvm-
# .oracle_jre_usage-
# .pinerc-
# .profile-
# .python_history-
# .pythonrc-.py
# .pythonstartup-
# .rnd-
# .rvm-
# .ServiceHub-
# ...

# %%
def f(x,l=[]):
    for i in range(x):
        l.append(i*i)
    print(l) 

f(2)
f(3,[3,2,1])
f(3)
# Out:
# [0, 1]
# [3, 2, 1, 0, 1, 4]
# [0, 1, 0, 1, 4]
